# %%
#DAG.DiGraph with 143 nodes and 125 edges
best_total_dif=34102.011312899675

# paper
#th1=.10 th2=best*.36
#ax+b
# output
# ['Foxm1', 'Rn45s', 'Ptchd1', 'Esco2', 'Dmrtb1', 'Myb', 'Bhlhe40']
# 7
# Total expression difference: 12269.762110702337

# %%
#ax+b
# th2=best * 0.9
# th2= 30691.810181609708
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12579.709256313849

# th2=best * 0.8
# th2= 27281.60905031974
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12579.709256313849

# th2=best * 0.7
# th2= 23871.40791902977
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12579.709256313849

# th2=best * 0.6
# th2= 20461.206787739804
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12579.709256313849


# th2=best * 0.5
# th2= 17051.005656449837
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12579.709256313849

# th2=best * 0.4
# th2= 13640.80452515987
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12579.709256313849

# th2=best * 0.3
# th2= 10230.603393869902
# ['Foxm1', 'Rn45s', 'Ptchd1', 'Esco2', 'Dmrtb1', 'Myb', 'Bhlhe40', 'Nipal1', 
# 'Fxyd5', 'Cx3cr1', 'P2ry12']
# 11
# Total expression difference: 9824.260108799801

# th2=best * 0.2
# th2= 6820.402262579935
# ['Foxm1', 'Rn45s', 'Ptchd1', 'Esco2', 'Dmrtb1', 'Myb', 'Bhlhe40', 'Nipal1', 
# 'Fxyd5', 'Cx3cr1', 'P2ry12', 'Selplg', 'Klf6', 'Laptm5']
# 14
# Total expression difference: 8475.07297559841

# th2=best * 0.1
# th2= 3410.2011312899676
# ['Foxm1', 'Rn45s', 'Ptchd1', 'Esco2', 'Dmrtb1', 'Myb', 'Bhlhe40', 'Nipal1', 'Fxyd5', 'Cx3cr1', 'P2ry12', 'Selplg', 'Klf6', 'Laptm5']
# 14
# Total expression difference: 8475.07297559841

# %%
#ax
# th2=best * 0.9
# th2= 30691.810181609708
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12587.104155740435

# th2=best * 0.8
# th2= 27281.60905031974
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12587.104155740435

# th2=best * 0.7
# th2= 23871.40791902977
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12587.104155740435

# th2=best * 0.6
# th2= 20461.206787739804
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12587.104155740435

# th2=best * 0.5
# th2= 17051.005656449837
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12587.104155740435

# th2=best * 0.4
# th2= 13640.80452515987
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12587.104155740435

# th2=best * 0.3
# th2= 10230.603393869902
# ['Foxm1', 'Rn45s', 'Esco2', 'Dmrtb1', 'Myb', 'Bhlhe40', 'E2f7', 'Nipal1', 'Fxyd5', 'Cx3cr1', 'P2ry12']
# 11
# Total expression difference: 9960.887663003952

# th2=best * 0.2
# th2= 6820.402262579935
# ['Foxm1', 'Rn45s', 'Esco2', 'Dmrtb1', 'Myb', 'Bhlhe40', 'E2f7', 'Nipal1', 'Fxyd5', 'Cx3cr1', 'P2ry12', 'Selplg', 'Klf6', 'Laptm5']
# 14
# Total expression difference: 8611.700529802562

# th2=best * 0.1
# th2= 3410.2011312899676
# ['Foxm1', 'Rn45s', 'Esco2', 'Dmrtb1', 'Myb', 'Bhlhe40', 'E2f7', 'Nipal1', 'Fxyd5', 'Cx3cr1', 'P2ry12', 'Selplg', 'Klf6', 'Laptm5']
# 14
# Total expression difference: 8611.700529802562

# %%
#a sqrt(x)
# th2=best * 0.9
# th2= 30691.810181609708
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12582.217741231201

# th2=best * 0.8
# th2= 27281.60905031974
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12582.217741231201

# th2=best * 0.7
# th2= 23871.40791902977
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12582.217741231201

# th2=best * 0.6
# th2= 20461.206787739804
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12582.217741231201

# th2=best * 0.5
# th2= 17051.005656449837
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12582.217741231201

# th2=best * 0.4
# th2= 13640.80452515987
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12582.217741231201

# th2=best * 0.3
# th2= 10230.603393869902
# ['Foxm1', 'Rn45s', 'Esco2', 'Dmrtb1', 'Myb', 'Bhlhe40', 'E2f7', 'E2f2', 'Brca1', 'Nipal1', 'Fxyd5', 'Cx3cr1', 'P2ry12']
# 13
# Total expression difference: 9957.23165131317

# th2=best * 0.2
# th2= 6820.402262579935
# ['Foxm1', 'Rn45s', 'Esco2', 'Dmrtb1', 'Myb', 'Bhlhe40', 'E2f7', 'E2f2', 'Brca1', 'Nipal1', 'Fxyd5', 'Cx3cr1', 'P2ry12', 'Selplg', 'Klf6', 'Laptm5']
# 16
# Total expression difference: 8608.04451811178

# th2=best * 0.1
# th2= 3410.2011312899676
# ['Foxm1', 'Rn45s', 'Esco2', 'Dmrtb1', 'Myb', 'Bhlhe40', 'E2f7', 'E2f2', 'Brca1', 'Nipal1', 'Fxyd5', 'Cx3cr1', 'P2ry12', 'Selplg', 'Klf6', 'Laptm5']
# 16
# Total expression difference: 8608.04451811178

# %%
#a sqrt(x) + b
# th2=best * 0.9
# th2= 30691.810181609708
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12627.932632573467

# th2=best * 0.8
# th2= 27281.60905031974
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12627.932632573467

# th2=best * 0.7
# th2= 23871.40791902977
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12627.932632573467

# th2=best * 0.6
# th2= 20461.206787739804
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12627.932632573467

# th2=best * 0.5
# th2= 17051.005656449837
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12627.932632573467

# th2=best * 0.4
# th2= 13640.80452515987
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12627.932632573467

# th2=best * 0.3
# th2= 10230.603393869902
# ['Foxm1', 'Rn45s', 'Ptchd1', 'Dmrtb1', 'Myb', 'Bhlhe40', 'Tfdp1', 'E2f2', 'Brca1', 'Nipal1', 'Fxyd5', 'Cx3cr1', 'P2ry12']
# 13
# Total expression difference: 9845.878730033779

# th2=best * 0.2
# th2= 6820.402262579935
# ['Foxm1', 'Rn45s', 'Ptchd1', 'Dmrtb1', 'Myb', 'Bhlhe40', 'Tfdp1', 'E2f2', 'Brca1', 'Nipal1', 'Fxyd5', 'Cx3cr1', 'P2ry12', 'Selplg', 'Klf6', 'Laptm5']
# 16
# Total expression difference: 8496.691596832388

# th2=best * 0.1
# th2= 3410.2011312899676
# ['Foxm1', 'Rn45s', 'Ptchd1', 'Dmrtb1', 'Myb', 'Bhlhe40', 'Tfdp1', 'E2f2', 'Brca1', 'Nipal1', 'Fxyd5', 'Cx3cr1', 'P2ry12', 'Selplg', 'Klf6', 'Laptm5']
# 16
# Total expression difference: 8496.691596832388

# %%
# a sin(x) + b cos(x)
# th2=best * 0.9
# th2= 30691.810181609708
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12737.629380514769

# th2=best * 0.8
# th2= 27281.60905031974
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12737.629380514769

# th2=best * 0.7
# th2= 23871.40791902977
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12737.629380514769

# th2=best * 0.6
# th2= 20461.206787739804
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12737.629380514769

# th2=best * 0.5
# th2= 17051.005656449837
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12737.629380514769

# th2=best * 0.4
# th2= 13640.80452515987
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12737.629380514769

# th2=best * 0.3
# th2= 10230.603393869902
# ['Foxm1', 'Rn45s', 'Esco2', 'Dmrtb1', 'Myb', 'Bhlhe40', 'Tfdp1', 'Yy1', 'E2f2', 'Nfkb2', 'Nipal1', 'Fxyd5', 'Cx3cr1', 'P2ry12']
# 14
# Total expression difference: 9959.18503439194

# th2=best * 0.2
# th2= 6820.402262579935
# ['Foxm1', 'Rn45s', 'Esco2', 'Dmrtb1', 'Myb', 'Bhlhe40', 'Tfdp1', 'Yy1', 'E2f2', 'Nfkb2', 'Nipal1', 'Fxyd5', 'Cx3cr1', 'P2ry12', 'Selplg', 'Klf6', 'Laptm5']        
# 17
# Total expression difference: 8609.997901190549

# th2=best * 0.1
# th2= 3410.2011312899676
# ['Foxm1', 'Rn45s', 'Esco2', 'Dmrtb1', 'Myb', 'Bhlhe40', 'Tfdp1', 'Yy1', 'E2f2', 'Nfkb2', 'Nipal1', 'Fxyd5', 'Cx3cr1', 'P2ry12', 'Selplg', 'Klf6', 'Laptm5']        
# 17
# Total expression difference: 8609.997901190549

# %%
#ax^2+b
# th2=best * 0.9
# th2= 30691.810181609708
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12578.00226204524

# th2=best * 0.8
# th2= 27281.60905031974
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12578.00226204524

# th2=best * 0.7
# th2= 23871.40791902977
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12578.00226204524

# th2=best * 0.6
# th2= 20461.206787739804
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12578.00226204524

# th2=best * 0.5
# th2= 17051.005656449837
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12578.00226204524

# th2=best * 0.4
# th2= 13640.80452515987
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12578.00226204524

# th2=best * 0.3
# th2= 10230.603393869902
# ['Foxm1', 'Rn45s', 'Ptchd1', 'Dmrtb1', 'Myb', 'Bhlhe40', 'Nipal1', 'Fxyd5', 'Cx3cr1', 'P2ry12']
# 10
# Total expression difference: 9822.913229783702

# th2=best * 0.2
# th2= 6820.402262579935
# ['Foxm1', 'Rn45s', 'Ptchd1', 'Dmrtb1', 'Myb', 'Bhlhe40', 'Nipal1', 'Fxyd5', 'Cx3cr1', 'P2ry12', 'Selplg', 'Klf6', 'Laptm5']
# 13
# Total expression difference: 8473.726096582312

# th2=best * 0.1
# th2= 3410.2011312899676
# ['Foxm1', 'Rn45s', 'Ptchd1', 'Dmrtb1', 'Myb', 'Bhlhe40', 'Nipal1', 'Fxyd5', 'Cx3cr1', 'P2ry12', 'Selplg', 'Klf6', 'Laptm5']
# 13
# Total expression difference: 8473.726096582312

# %%
#ax^2+bX=0.5
# th2=best * 0.9
# th2= 30691.810181609708
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12581.727104087333

# th2=best * 0.8
# th2= 27281.60905031974
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12581.727104087333

# th2=best * 0.7
# th2= 23871.40791902977
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12581.727104087333

# th2=best * 0.6
# th2= 20461.206787739804
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12581.727104087333

# th2=best * 0.5
# th2= 17051.005656449837
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12581.727104087333

# th2=best * 0.4
# th2= 13640.80452515987
# ['Foxm1', 'Rn45s']
# 2
# Total expression difference: 12581.727104087333

# th2=best * 0.3
# th2= 10230.603393869902
# ['Foxm1', 'Rn45s', 'Casc5', 'Esco2', 'Dmrtb1', 'Myb', 'Bhlhe40', 'Nipal1', 'Fxyd5', 'Cx3cr1', 'P2ry12']
# 11
# Total expression difference: 9959.209067849311

# th2=best * 0.2
# th2= 6820.402262579935
# ['Foxm1', 'Rn45s', 'Casc5', 'Esco2', 'Dmrtb1', 'Myb', 'Bhlhe40', 'Nipal1', 'Fxyd5', 'Cx3cr1', 'P2ry12', 'Selplg', 'Klf6', 'Laptm5']
# 14
# Total expression difference: 8610.02193464792

# th2=best * 0.1
# th2= 3410.2011312899676
# ['Foxm1', 'Rn45s', 'Casc5', 'Esco2', 'Dmrtb1', 'Myb', 'Bhlhe40', 'Nipal1', 'Fxyd5', 'Cx3cr1', 'P2ry12', 'Selplg', 'Klf6', 'Laptm5']
# 14
# Total expression difference: 8610.02193464792
